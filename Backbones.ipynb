# %%
import torch
import pandas as pd
import numpy as np
from scipy.stats import ranksums
from scipy.stats import gaussian_kde
import matplotlib.pyplot as plt
from itertools import chain

# %%
base_path='***'
m='gemma_2_2b'
df1fac = pd.read_csv(f'{base_path}{m}_fac_part1.csv')
df2fac = pd.read_csv(f'{base_path}{m}_fac_part2.csv')
df3fac = pd.read_csv(f'{base_path}{m}_fac_part3.csv')
merged_dffac = pd.concat([df1fac, df2fac, df3fac], ignore_index=True)
df1cau = pd.read_csv(f'{base_path}{m}_cau_part1.csv')
df2cau = pd.read_csv(f'{base_path}{m}_cau_part2.csv')
df3cau = pd.read_csv(f'{base_path}{m}_cau_part3.csv')
merged_dfcau = pd.concat([df1cau, df2cau, df3cau], ignore_index=True)

df1afac = pd.read_csv(f'{base_path}merged_part1_fac.csv')
df2afac = pd.read_csv(f'{base_path}merged_part2_fac.csv')
df3afac = pd.read_csv(f'{base_path}merged_part3_fac.csv')
merged_dfafac = pd.concat([df1afac, df2afac, df3afac], ignore_index=True)
df1acau = pd.read_csv(f'{base_path}merged_part1_cau.csv')
df2acau = pd.read_csv(f'{base_path}merged_part2_cau.csv')
df3acau = pd.read_csv(f'{base_path}merged_part3_cau.csv')
merged_dfacau = pd.concat([df1acau, df2acau, df3acau], ignore_index=True)

merged_dffac['origin'] = merged_dfafac['origin']
merged_dfcau['origin'] = merged_dfacau['origin']

fac = merged_dffac[merged_dffac["origin"] == 'fac']
nofac = merged_dffac[merged_dffac["origin"] == 'nofac']
#var_name = f"cau_{m}"
#globals()[var_name] 
cau = merged_dfcau[merged_dfcau["origin"] == 'cau']
nocau = merged_dfcau[merged_dfcau["origin"] == 'nocau']

var_name = f"facprob_{m}"
globals()[var_name] = fac['Prob_Yes']/(fac['Prob_Yes']+fac['Prob_No'])
var_name = f"nofacprob_{m}"
globals()[var_name] = nofac['Prob_Yes']/(nofac['Prob_Yes']+nofac['Prob_No'])
var_name = f"cauprob_{m}"
globals()[var_name] = cau['Prob_Yes']/(cau['Prob_Yes']+cau['Prob_No'])
var_name = f"nocauprob_{m}"
globals()[var_name] = nocau['Prob_Yes']/(nocau['Prob_Yes']+nocau['Prob_No'])


df1fac_pos = pd.read_csv(f'{base_path}{m}_fac_pos_part1.csv')
df2fac_pos = pd.read_csv(f'{base_path}{m}_fac_pos_part2.csv')
df3fac_pos = pd.read_csv(f'{base_path}{m}_fac_pos_part3.csv')
merged_dffac_pos = pd.concat([df1fac_pos, df2fac_pos, df3fac_pos], ignore_index=True)
df1cau_pos = pd.read_csv(f'{base_path}{m}_cau_pos_part1.csv')
df2cau_pos = pd.read_csv(f'{base_path}{m}_cau_pos_part2.csv')
df3cau_pos = pd.read_csv(f'{base_path}{m}_cau_pos_part3.csv')
merged_dfcau_pos = pd.concat([df1cau_pos, df2cau_pos, df3cau_pos], ignore_index=True)

df1afac = pd.read_csv(f'{base_path}merged_part1_fac.csv')
df2afac = pd.read_csv(f'{base_path}merged_part2_fac.csv')
df3afac = pd.read_csv(f'{base_path}merged_part3_fac.csv')
merged_dfafac = pd.concat([df1afac, df2afac, df3afac], ignore_index=True)
df1acau = pd.read_csv(f'{base_path}merged_part1_cau.csv')
df2acau = pd.read_csv(f'{base_path}merged_part2_cau.csv')
df3acau = pd.read_csv(f'{base_path}merged_part3_cau.csv')
merged_dfacau = pd.concat([df1acau, df2acau, df3acau], ignore_index=True)

merged_dffac_pos['origin'] = merged_dfafac['origin']
merged_dfcau_pos['origin'] = merged_dfacau['origin']

fac_pos = merged_dffac_pos[merged_dffac_pos["origin"] == 'fac']
nofac_pos = merged_dffac_pos[merged_dffac_pos["origin"] == 'nofac']
#var_name = f"cau_{m}"
#globals()[var_name] 
cau_pos = merged_dfcau_pos[merged_dfcau_pos["origin"] == 'cau']
nocau_pos = merged_dfcau_pos[merged_dfcau_pos["origin"] == 'nocau']

var_name = f"facprob_{m}_pos"
globals()[var_name] = fac_pos['Prob_Yes']/(fac_pos['Prob_Yes']+fac_pos['Prob_No'])
var_name = f"nofacprob_{m}_pos"
globals()[var_name] = nofac_pos['Prob_Yes']/(nofac_pos['Prob_Yes']+nofac_pos['Prob_No'])
var_name = f"cauprob_{m}_pos"
globals()[var_name] = cau_pos['Prob_Yes']/(cau_pos['Prob_Yes']+cau_pos['Prob_No'])
var_name = f"nocauprob_{m}_pos"
globals()[var_name] = nocau_pos['Prob_Yes']/(nocau_pos['Prob_Yes']+nocau_pos['Prob_No'])


var_name = f"facprob_{m}_ave"
globals()[var_name] = (globals()[f"facprob_{m}"]+globals()[f"facprob_{m}_pos"])/2
var_name = f"nofacprob_{m}_ave"
globals()[var_name] = (globals()[f"nofacprob_{m}"]+globals()[f"nofacprob_{m}_pos"])/2
var_name = f"cauprob_{m}_ave"
globals()[var_name] = (globals()[f"cauprob_{m}"]+globals()[f"cauprob_{m}_pos"])/2
var_name = f"nocauprob_{m}_ave"
globals()[var_name] = (globals()[f"nocauprob_{m}"]+globals()[f"nocauprob_{m}_pos"])/2


m='gemma_2_9b'
df1fac = pd.read_csv(f'{base_path}{m}_fac_part1.csv')
df2fac = pd.read_csv(f'{base_path}{m}_fac_part2.csv')
df3fac = pd.read_csv(f'{base_path}{m}_fac_part3.csv')
merged_dffac = pd.concat([df1fac, df2fac, df3fac], ignore_index=True)
df1cau = pd.read_csv(f'{base_path}{m}_cau_part1.csv')
df2cau = pd.read_csv(f'{base_path}{m}_cau_part2.csv')
df3cau = pd.read_csv(f'{base_path}{m}_cau_part3.csv')
merged_dfcau = pd.concat([df1cau, df2cau, df3cau], ignore_index=True)

df1afac = pd.read_csv(f'{base_path}merged_part1_fac.csv')
df2afac = pd.read_csv(f'{base_path}merged_part2_fac.csv')
df3afac = pd.read_csv(f'{base_path}merged_part3_fac.csv')
merged_dfafac = pd.concat([df1afac, df2afac, df3afac], ignore_index=True)
df1acau = pd.read_csv(f'{base_path}merged_part1_cau.csv')
df2acau = pd.read_csv(f'{base_path}merged_part2_cau.csv')
df3acau = pd.read_csv(f'{base_path}merged_part3_cau.csv')
merged_dfacau = pd.concat([df1acau, df2acau, df3acau], ignore_index=True)

merged_dffac['origin'] = merged_dfafac['origin']
merged_dfcau['origin'] = merged_dfacau['origin']

fac = merged_dffac[merged_dffac["origin"] == 'fac']
nofac = merged_dffac[merged_dffac["origin"] == 'nofac']
#var_name = f"cau_{m}"
#globals()[var_name] 
cau = merged_dfcau[merged_dfcau["origin"] == 'cau']
nocau = merged_dfcau[merged_dfcau["origin"] == 'nocau']

var_name = f"facprob_{m}"
globals()[var_name] = fac['Prob_Yes']/(fac['Prob_Yes']+fac['Prob_No'])
var_name = f"nofacprob_{m}"
globals()[var_name] = nofac['Prob_Yes']/(nofac['Prob_Yes']+nofac['Prob_No'])
var_name = f"cauprob_{m}"
globals()[var_name] = cau['Prob_Yes']/(cau['Prob_Yes']+cau['Prob_No'])
var_name = f"nocauprob_{m}"
globals()[var_name] = nocau['Prob_Yes']/(nocau['Prob_Yes']+nocau['Prob_No'])


df1fac_pos = pd.read_csv(f'{base_path}{m}_fac_pos_part1.csv')
df2fac_pos = pd.read_csv(f'{base_path}{m}_fac_pos_part2.csv')
df3fac_pos = pd.read_csv(f'{base_path}{m}_fac_pos_part3.csv')
merged_dffac_pos = pd.concat([df1fac_pos, df2fac_pos, df3fac_pos], ignore_index=True)
df1cau_pos = pd.read_csv(f'{base_path}{m}_cau_pos_part1.csv')
df2cau_pos = pd.read_csv(f'{base_path}{m}_cau_pos_part2.csv')
df3cau_pos = pd.read_csv(f'{base_path}{m}_cau_pos_part3.csv')
merged_dfcau_pos = pd.concat([df1cau_pos, df2cau_pos, df3cau_pos], ignore_index=True)

df1afac = pd.read_csv(f'{base_path}merged_part1_fac.csv')
df2afac = pd.read_csv(f'{base_path}merged_part2_fac.csv')
df3afac = pd.read_csv(f'{base_path}merged_part3_fac.csv')
merged_dfafac = pd.concat([df1afac, df2afac, df3afac], ignore_index=True)
df1acau = pd.read_csv(f'{base_path}merged_part1_cau.csv')
df2acau = pd.read_csv(f'{base_path}merged_part2_cau.csv')
df3acau = pd.read_csv(f'{base_path}merged_part3_cau.csv')
merged_dfacau = pd.concat([df1acau, df2acau, df3acau], ignore_index=True)

merged_dffac_pos['origin'] = merged_dfafac['origin']
merged_dfcau_pos['origin'] = merged_dfacau['origin']

fac_pos = merged_dffac_pos[merged_dffac_pos["origin"] == 'fac']
nofac_pos = merged_dffac_pos[merged_dffac_pos["origin"] == 'nofac']
#var_name = f"cau_{m}"
#globals()[var_name] 
cau_pos = merged_dfcau_pos[merged_dfcau_pos["origin"] == 'cau']
nocau_pos = merged_dfcau_pos[merged_dfcau_pos["origin"] == 'nocau']

var_name = f"facprob_{m}_pos"
globals()[var_name] = fac_pos['Prob_Yes']/(fac_pos['Prob_Yes']+fac_pos['Prob_No'])
var_name = f"nofacprob_{m}_pos"
globals()[var_name] = nofac_pos['Prob_Yes']/(nofac_pos['Prob_Yes']+nofac_pos['Prob_No'])
var_name = f"cauprob_{m}_pos"
globals()[var_name] = cau_pos['Prob_Yes']/(cau_pos['Prob_Yes']+cau_pos['Prob_No'])
var_name = f"nocauprob_{m}_pos"
globals()[var_name] = nocau_pos['Prob_Yes']/(nocau_pos['Prob_Yes']+nocau_pos['Prob_No'])


var_name = f"facprob_{m}_ave"
globals()[var_name] = (globals()[f"facprob_{m}"]+globals()[f"facprob_{m}_pos"])/2
var_name = f"nofacprob_{m}_ave"
globals()[var_name] = (globals()[f"nofacprob_{m}"]+globals()[f"nofacprob_{m}_pos"])/2
var_name = f"cauprob_{m}_ave"
globals()[var_name] = (globals()[f"cauprob_{m}"]+globals()[f"cauprob_{m}_pos"])/2
var_name = f"nocauprob_{m}_ave"
globals()[var_name] = (globals()[f"nocauprob_{m}"]+globals()[f"nocauprob_{m}_pos"])/2



m='llama_32_3b'
df1fac = pd.read_csv(f'{base_path}{m}_fac_part1.csv')
df2fac = pd.read_csv(f'{base_path}{m}_fac_part2.csv')
df3fac = pd.read_csv(f'{base_path}{m}_fac_part3.csv')
merged_dffac = pd.concat([df1fac, df2fac, df3fac], ignore_index=True)
df1cau = pd.read_csv(f'{base_path}{m}_cau_part1.csv')
df2cau = pd.read_csv(f'{base_path}{m}_cau_part2.csv')
df3cau = pd.read_csv(f'{base_path}{m}_cau_part3.csv')
merged_dfcau = pd.concat([df1cau, df2cau, df3cau], ignore_index=True)

df1afac = pd.read_csv(f'{base_path}merged_part1_fac.csv')
df2afac = pd.read_csv(f'{base_path}merged_part2_fac.csv')
df3afac = pd.read_csv(f'{base_path}merged_part3_fac.csv')
merged_dfafac = pd.concat([df1afac, df2afac, df3afac], ignore_index=True)
df1acau = pd.read_csv(f'{base_path}merged_part1_cau.csv')
df2acau = pd.read_csv(f'{base_path}merged_part2_cau.csv')
df3acau = pd.read_csv(f'{base_path}merged_part3_cau.csv')
merged_dfacau = pd.concat([df1acau, df2acau, df3acau], ignore_index=True)

merged_dffac['origin'] = merged_dfafac['origin']
merged_dfcau['origin'] = merged_dfacau['origin']

fac = merged_dffac[merged_dffac["origin"] == 'fac']
nofac = merged_dffac[merged_dffac["origin"] == 'nofac']
#var_name = f"cau_{m}"
#globals()[var_name] 
cau = merged_dfcau[merged_dfcau["origin"] == 'cau']
nocau = merged_dfcau[merged_dfcau["origin"] == 'nocau']

var_name = f"facprob_{m}"
globals()[var_name] = fac['Prob_No']/(fac['Prob_Yes']+fac['Prob_No'])
var_name = f"nofacprob_{m}"
globals()[var_name] = nofac['Prob_No']/(nofac['Prob_Yes']+nofac['Prob_No'])
var_name = f"cauprob_{m}"
globals()[var_name] = cau['Prob_No']/(cau['Prob_Yes']+cau['Prob_No'])
var_name = f"nocauprob_{m}"
globals()[var_name] = nocau['Prob_No']/(nocau['Prob_Yes']+nocau['Prob_No'])


df1fac_pos = pd.read_csv(f'{base_path}{m}_fac_pos_part1.csv')
df2fac_pos = pd.read_csv(f'{base_path}{m}_fac_pos_part2.csv')
df3fac_pos = pd.read_csv(f'{base_path}{m}_fac_pos_part3.csv')
merged_dffac_pos = pd.concat([df1fac_pos, df2fac_pos, df3fac_pos], ignore_index=True)
df1cau_pos = pd.read_csv(f'{base_path}{m}_cau_pos_part1.csv')
df2cau_pos = pd.read_csv(f'{base_path}{m}_cau_pos_part2.csv')
df3cau_pos = pd.read_csv(f'{base_path}{m}_cau_pos_part3.csv')
merged_dfcau_pos = pd.concat([df1cau_pos, df2cau_pos, df3cau_pos], ignore_index=True)

df1afac = pd.read_csv(f'{base_path}merged_part1_fac.csv')
df2afac = pd.read_csv(f'{base_path}merged_part2_fac.csv')
df3afac = pd.read_csv(f'{base_path}merged_part3_fac.csv')
merged_dfafac = pd.concat([df1afac, df2afac, df3afac], ignore_index=True)
df1acau = pd.read_csv(f'{base_path}merged_part1_cau.csv')
df2acau = pd.read_csv(f'{base_path}merged_part2_cau.csv')
df3acau = pd.read_csv(f'{base_path}merged_part3_cau.csv')
merged_dfacau = pd.concat([df1acau, df2acau, df3acau], ignore_index=True)

merged_dffac_pos['origin'] = merged_dfafac['origin']
merged_dfcau_pos['origin'] = merged_dfacau['origin']

fac_pos = merged_dffac_pos[merged_dffac_pos["origin"] == 'fac']
nofac_pos = merged_dffac_pos[merged_dffac_pos["origin"] == 'nofac']
#var_name = f"cau_{m}"
#globals()[var_name] 
cau_pos = merged_dfcau_pos[merged_dfcau_pos["origin"] == 'cau']
nocau_pos = merged_dfcau_pos[merged_dfcau_pos["origin"] == 'nocau']

var_name = f"facprob_{m}_pos"
globals()[var_name] = fac_pos['Prob_No']/(fac_pos['Prob_Yes']+fac_pos['Prob_No'])
var_name = f"nofacprob_{m}_pos"
globals()[var_name] = nofac_pos['Prob_No']/(nofac_pos['Prob_Yes']+nofac_pos['Prob_No'])
var_name = f"cauprob_{m}_pos"
globals()[var_name] = cau_pos['Prob_No']/(cau_pos['Prob_Yes']+cau_pos['Prob_No'])
var_name = f"nocauprob_{m}_pos"
globals()[var_name] = nocau_pos['Prob_No']/(nocau_pos['Prob_Yes']+nocau_pos['Prob_No'])


var_name = f"facprob_{m}_ave"
globals()[var_name] = 1-np.maximum(globals()[f"facprob_{m}"],globals()[f"facprob_{m}_pos"])
var_name = f"nofacprob_{m}_ave"
globals()[var_name] = 1-np.maximum(globals()[f"nofacprob_{m}"],globals()[f"nofacprob_{m}_pos"])
var_name = f"cauprob_{m}_ave"
globals()[var_name] = 1-np.maximum(globals()[f"cauprob_{m}"],globals()[f"cauprob_{m}_pos"])
var_name = f"nocauprob_{m}_ave"
globals()[var_name] = 1-np.maximum(globals()[f"nocauprob_{m}"],globals()[f"nocauprob_{m}_pos"])



m='llama_31_8b'
df1fac = pd.read_csv(f'{base_path}{m}_fac_part1.csv')
df2fac = pd.read_csv(f'{base_path}{m}_fac_part2.csv')
df3fac = pd.read_csv(f'{base_path}{m}_fac_part3.csv')
merged_dffac = pd.concat([df1fac, df2fac, df3fac], ignore_index=True)
df1cau = pd.read_csv(f'{base_path}{m}_cau_part1.csv')
df2cau = pd.read_csv(f'{base_path}{m}_cau_part2.csv')
df3cau = pd.read_csv(f'{base_path}{m}_cau_part3.csv')
merged_dfcau = pd.concat([df1cau, df2cau, df3cau], ignore_index=True)

df1afac = pd.read_csv(f'{base_path}merged_part1_fac.csv')
df2afac = pd.read_csv(f'{base_path}merged_part2_fac.csv')
df3afac = pd.read_csv(f'{base_path}merged_part3_fac.csv')
merged_dfafac = pd.concat([df1afac, df2afac, df3afac], ignore_index=True)
df1acau = pd.read_csv(f'{base_path}merged_part1_cau.csv')
df2acau = pd.read_csv(f'{base_path}merged_part2_cau.csv')
df3acau = pd.read_csv(f'{base_path}merged_part3_cau.csv')
merged_dfacau = pd.concat([df1acau, df2acau, df3acau], ignore_index=True)

merged_dffac['origin'] = merged_dfafac['origin']
merged_dfcau['origin'] = merged_dfacau['origin']

fac = merged_dffac[merged_dffac["origin"] == 'fac']
nofac = merged_dffac[merged_dffac["origin"] == 'nofac']
#var_name = f"cau_{m}"
#globals()[var_name] 
cau = merged_dfcau[merged_dfcau["origin"] == 'cau']
nocau = merged_dfcau[merged_dfcau["origin"] == 'nocau']

var_name = f"facprob_{m}"
globals()[var_name] = fac['Prob_No']/(fac['Prob_Yes']+fac['Prob_No'])
var_name = f"nofacprob_{m}"
globals()[var_name] = nofac['Prob_No']/(nofac['Prob_Yes']+nofac['Prob_No'])
var_name = f"cauprob_{m}"
globals()[var_name] = cau['Prob_No']/(cau['Prob_Yes']+cau['Prob_No'])
var_name = f"nocauprob_{m}"
globals()[var_name] = nocau['Prob_No']/(nocau['Prob_Yes']+nocau['Prob_No'])


df1fac_pos = pd.read_csv(f'{base_path}{m}_fac_pos_part1.csv')
df2fac_pos = pd.read_csv(f'{base_path}{m}_fac_pos_part2.csv')
df3fac_pos = pd.read_csv(f'{base_path}{m}_fac_pos_part3.csv')
merged_dffac_pos = pd.concat([df1fac_pos, df2fac_pos, df3fac_pos], ignore_index=True)
df1cau_pos = pd.read_csv(f'{base_path}{m}_cau_pos_part1.csv')
df2cau_pos = pd.read_csv(f'{base_path}{m}_cau_pos_part2.csv')
df3cau_pos = pd.read_csv(f'{base_path}{m}_cau_pos_part3.csv')
merged_dfcau_pos = pd.concat([df1cau_pos, df2cau_pos, df3cau_pos], ignore_index=True)

df1afac = pd.read_csv(f'{base_path}merged_part1_fac.csv')
df2afac = pd.read_csv(f'{base_path}merged_part2_fac.csv')
df3afac = pd.read_csv(f'{base_path}merged_part3_fac.csv')
merged_dfafac = pd.concat([df1afac, df2afac, df3afac], ignore_index=True)
df1acau = pd.read_csv(f'{base_path}merged_part1_cau.csv')
df2acau = pd.read_csv(f'{base_path}merged_part2_cau.csv')
df3acau = pd.read_csv(f'{base_path}merged_part3_cau.csv')
merged_dfacau = pd.concat([df1acau, df2acau, df3acau], ignore_index=True)

merged_dffac_pos['origin'] = merged_dfafac['origin']
merged_dfcau_pos['origin'] = merged_dfacau['origin']

fac_pos = merged_dffac_pos[merged_dffac_pos["origin"] == 'fac']
nofac_pos = merged_dffac_pos[merged_dffac_pos["origin"] == 'nofac']
#var_name = f"cau_{m}"
#globals()[var_name] 
cau_pos = merged_dfcau_pos[merged_dfcau_pos["origin"] == 'cau']
nocau_pos = merged_dfcau_pos[merged_dfcau_pos["origin"] == 'nocau']

var_name = f"facprob_{m}_pos"
globals()[var_name] = fac_pos['Prob_No']/(fac_pos['Prob_Yes']+fac_pos['Prob_No'])
var_name = f"nofacprob_{m}_pos"
globals()[var_name] = nofac_pos['Prob_No']/(nofac_pos['Prob_Yes']+nofac_pos['Prob_No'])
var_name = f"cauprob_{m}_pos"
globals()[var_name] = cau_pos['Prob_No']/(cau_pos['Prob_Yes']+cau_pos['Prob_No'])
var_name = f"nocauprob_{m}_pos"
globals()[var_name] = nocau_pos['Prob_No']/(nocau_pos['Prob_Yes']+nocau_pos['Prob_No'])


var_name = f"facprob_{m}_ave"
globals()[var_name] = 1-np.maximum(globals()[f"facprob_{m}"],globals()[f"facprob_{m}_pos"])
var_name = f"nofacprob_{m}_ave"
globals()[var_name] = 1-np.maximum(globals()[f"nofacprob_{m}"],globals()[f"nofacprob_{m}_pos"])
var_name = f"cauprob_{m}_ave"
globals()[var_name] = 1-np.maximum(globals()[f"cauprob_{m}"],globals()[f"cauprob_{m}_pos"])
var_name = f"nocauprob_{m}_ave"
globals()[var_name] = 1-np.maximum(globals()[f"nocauprob_{m}"],globals()[f"nocauprob_{m}_pos"])


m='phi_35_mini'
df1fac = pd.read_csv(f'{base_path}{m}_fac_part1.csv')
df2fac = pd.read_csv(f'{base_path}{m}_fac_part2.csv')
df3fac = pd.read_csv(f'{base_path}{m}_fac_part3.csv')
merged_dffac = pd.concat([df1fac, df2fac, df3fac], ignore_index=True)
df1cau = pd.read_csv(f'{base_path}{m}_cau_part1.csv')
df2cau = pd.read_csv(f'{base_path}{m}_cau_part2.csv')
df3cau = pd.read_csv(f'{base_path}{m}_cau_part3.csv')
merged_dfcau = pd.concat([df1cau, df2cau, df3cau], ignore_index=True)

df1afac = pd.read_csv(f'{base_path}merged_part1_fac.csv')
df2afac = pd.read_csv(f'{base_path}merged_part2_fac.csv')
df3afac = pd.read_csv(f'{base_path}merged_part3_fac.csv')
merged_dfafac = pd.concat([df1afac, df2afac, df3afac], ignore_index=True)
df1acau = pd.read_csv(f'{base_path}merged_part1_cau.csv')
df2acau = pd.read_csv(f'{base_path}merged_part2_cau.csv')
df3acau = pd.read_csv(f'{base_path}merged_part3_cau.csv')
merged_dfacau = pd.concat([df1acau, df2acau, df3acau], ignore_index=True)

merged_dffac['origin'] = merged_dfafac['origin']
merged_dfcau['origin'] = merged_dfacau['origin']

fac = merged_dffac[merged_dffac["origin"] == 'fac']
nofac = merged_dffac[merged_dffac["origin"] == 'nofac']
#var_name = f"cau_{m}"
#globals()[var_name] 
cau = merged_dfcau[merged_dfcau["origin"] == 'cau']
nocau = merged_dfcau[merged_dfcau["origin"] == 'nocau']

var_name = f"facprob_{m}"
globals()[var_name] = fac['Prob_Yes']/(fac['Prob_Yes']+fac['Prob_No'])
var_name = f"nofacprob_{m}"
globals()[var_name] = nofac['Prob_Yes']/(nofac['Prob_Yes']+nofac['Prob_No'])
var_name = f"cauprob_{m}"
globals()[var_name] = cau['Prob_Yes']/(cau['Prob_Yes']+cau['Prob_No'])
var_name = f"nocauprob_{m}"
globals()[var_name] = nocau['Prob_Yes']/(nocau['Prob_Yes']+nocau['Prob_No'])


df1fac_pos = pd.read_csv(f'{base_path}{m}_fac_pos_part1.csv')
df2fac_pos = pd.read_csv(f'{base_path}{m}_fac_pos_part2.csv')
df3fac_pos = pd.read_csv(f'{base_path}{m}_fac_pos_part3.csv')
merged_dffac_pos = pd.concat([df1fac_pos, df2fac_pos, df3fac_pos], ignore_index=True)
df1cau_pos = pd.read_csv(f'{base_path}{m}_cau_pos_part1.csv')
df2cau_pos = pd.read_csv(f'{base_path}{m}_cau_pos_part2.csv')
df3cau_pos = pd.read_csv(f'{base_path}{m}_cau_pos_part3.csv')
merged_dfcau_pos = pd.concat([df1cau_pos, df2cau_pos, df3cau_pos], ignore_index=True)

df1afac = pd.read_csv(f'{base_path}merged_part1_fac.csv')
df2afac = pd.read_csv(f'{base_path}merged_part2_fac.csv')
df3afac = pd.read_csv(f'{base_path}merged_part3_fac.csv')
merged_dfafac = pd.concat([df1afac, df2afac, df3afac], ignore_index=True)
df1acau = pd.read_csv(f'{base_path}merged_part1_cau.csv')
df2acau = pd.read_csv(f'{base_path}merged_part2_cau.csv')
df3acau = pd.read_csv(f'{base_path}merged_part3_cau.csv')
merged_dfacau = pd.concat([df1acau, df2acau, df3acau], ignore_index=True)

merged_dffac_pos['origin'] = merged_dfafac['origin']
merged_dfcau_pos['origin'] = merged_dfacau['origin']

fac_pos = merged_dffac_pos[merged_dffac_pos["origin"] == 'fac']
nofac_pos = merged_dffac_pos[merged_dffac_pos["origin"] == 'nofac']
#var_name = f"cau_{m}"
#globals()[var_name] 
cau_pos = merged_dfcau_pos[merged_dfcau_pos["origin"] == 'cau']
nocau_pos = merged_dfcau_pos[merged_dfcau_pos["origin"] == 'nocau']

var_name = f"facprob_{m}_pos"
globals()[var_name] = fac_pos['Prob_Yes']/(fac_pos['Prob_Yes']+fac_pos['Prob_No'])
var_name = f"nofacprob_{m}_pos"
globals()[var_name] = nofac_pos['Prob_Yes']/(nofac_pos['Prob_Yes']+nofac_pos['Prob_No'])
var_name = f"cauprob_{m}_pos"
globals()[var_name] = cau_pos['Prob_Yes']/(cau_pos['Prob_Yes']+cau_pos['Prob_No'])
var_name = f"nocauprob_{m}_pos"
globals()[var_name] = nocau_pos['Prob_Yes']/(nocau_pos['Prob_Yes']+nocau_pos['Prob_No'])


var_name = f"facprob_{m}_ave"
globals()[var_name] = (globals()[f"facprob_{m}"]+globals()[f"facprob_{m}_pos"])/2
var_name = f"nofacprob_{m}_ave"
globals()[var_name] = (globals()[f"nofacprob_{m}"]+globals()[f"nofacprob_{m}_pos"])/2
var_name = f"cauprob_{m}_ave"
globals()[var_name] = (globals()[f"cauprob_{m}"]+globals()[f"cauprob_{m}_pos"])/2
var_name = f"nocauprob_{m}_ave"
globals()[var_name] = (globals()[f"nocauprob_{m}"]+globals()[f"nocauprob_{m}_pos"])/2




m='phi_35_MoE'
df1fac = pd.read_csv(f'{base_path}{m}_fac_part1.csv')
df2fac = pd.read_csv(f'{base_path}{m}_fac_part2.csv')
df3fac = pd.read_csv(f'{base_path}{m}_fac_part3.csv')
merged_dffac = pd.concat([df1fac, df2fac, df3fac], ignore_index=True)
df1cau = pd.read_csv(f'{base_path}{m}_cau_part1.csv')
df2cau = pd.read_csv(f'{base_path}{m}_cau_part2.csv')
df3cau = pd.read_csv(f'{base_path}{m}_cau_part3.csv')
merged_dfcau = pd.concat([df1cau, df2cau, df3cau], ignore_index=True)

df1afac = pd.read_csv(f'{base_path}merged_part1_fac.csv')
df2afac = pd.read_csv(f'{base_path}merged_part2_fac.csv')
df3afac = pd.read_csv(f'{base_path}merged_part3_fac.csv')
merged_dfafac = pd.concat([df1afac, df2afac, df3afac], ignore_index=True)
df1acau = pd.read_csv(f'{base_path}merged_part1_cau.csv')
df2acau = pd.read_csv(f'{base_path}merged_part2_cau.csv')
df3acau = pd.read_csv(f'{base_path}merged_part3_cau.csv')
merged_dfacau = pd.concat([df1acau, df2acau, df3acau], ignore_index=True)

merged_dffac['origin'] = merged_dfafac['origin']
merged_dfcau['origin'] = merged_dfacau['origin']

fac = merged_dffac[merged_dffac["origin"] == 'fac']
nofac = merged_dffac[merged_dffac["origin"] == 'nofac']
#var_name = f"cau_{m}"
#globals()[var_name] 
cau = merged_dfcau[merged_dfcau["origin"] == 'cau']
nocau = merged_dfcau[merged_dfcau["origin"] == 'nocau']

var_name = f"facprob_{m}"
globals()[var_name] = fac['Prob_Yes']/(fac['Prob_Yes']+fac['Prob_No'])
var_name = f"nofacprob_{m}"
globals()[var_name] = nofac['Prob_Yes']/(nofac['Prob_Yes']+nofac['Prob_No'])
var_name = f"cauprob_{m}"
globals()[var_name] = cau['Prob_Yes']/(cau['Prob_Yes']+cau['Prob_No'])
var_name = f"nocauprob_{m}"
globals()[var_name] = nocau['Prob_Yes']/(nocau['Prob_Yes']+nocau['Prob_No'])


df1fac_pos = pd.read_csv(f'{base_path}{m}_fac_pos_part1.csv')
df2fac_pos = pd.read_csv(f'{base_path}{m}_fac_pos_part2.csv')
df3fac_pos = pd.read_csv(f'{base_path}{m}_fac_pos_part3.csv')
merged_dffac_pos = pd.concat([df1fac_pos, df2fac_pos, df3fac_pos], ignore_index=True)
df1cau_pos = pd.read_csv(f'{base_path}{m}_cau_pos_part1.csv')
df2cau_pos = pd.read_csv(f'{base_path}{m}_cau_pos_part2.csv')
df3cau_pos = pd.read_csv(f'{base_path}{m}_cau_pos_part3.csv')
merged_dfcau_pos = pd.concat([df1cau_pos, df2cau_pos, df3cau_pos], ignore_index=True)

df1afac = pd.read_csv(f'{base_path}merged_part1_fac.csv')
df2afac = pd.read_csv(f'{base_path}merged_part2_fac.csv')
df3afac = pd.read_csv(f'{base_path}merged_part3_fac.csv')
merged_dfafac = pd.concat([df1afac, df2afac, df3afac], ignore_index=True)
df1acau = pd.read_csv(f'{base_path}merged_part1_cau.csv')
df2acau = pd.read_csv(f'{base_path}merged_part2_cau.csv')
df3acau = pd.read_csv(f'{base_path}merged_part3_cau.csv')
merged_dfacau = pd.concat([df1acau, df2acau, df3acau], ignore_index=True)

merged_dffac_pos['origin'] = merged_dfafac['origin']
merged_dfcau_pos['origin'] = merged_dfacau['origin']

fac_pos = merged_dffac_pos[merged_dffac_pos["origin"] == 'fac']
nofac_pos = merged_dffac_pos[merged_dffac_pos["origin"] == 'nofac']
#var_name = f"cau_{m}"
#globals()[var_name] 
cau_pos = merged_dfcau_pos[merged_dfcau_pos["origin"] == 'cau']
nocau_pos = merged_dfcau_pos[merged_dfcau_pos["origin"] == 'nocau']

var_name = f"facprob_{m}_pos"
globals()[var_name] = fac_pos['Prob_Yes']/(fac_pos['Prob_Yes']+fac_pos['Prob_No'])
var_name = f"nofacprob_{m}_pos"
globals()[var_name] = nofac_pos['Prob_Yes']/(nofac_pos['Prob_Yes']+nofac_pos['Prob_No'])
var_name = f"cauprob_{m}_pos"
globals()[var_name] = cau_pos['Prob_Yes']/(cau_pos['Prob_Yes']+cau_pos['Prob_No'])
var_name = f"nocauprob_{m}_pos"
globals()[var_name] = nocau_pos['Prob_Yes']/(nocau_pos['Prob_Yes']+nocau_pos['Prob_No'])


var_name = f"facprob_{m}_ave"
globals()[var_name] = (globals()[f"facprob_{m}"]+globals()[f"facprob_{m}_pos"])/2
var_name = f"nofacprob_{m}_ave"
globals()[var_name] = (globals()[f"nofacprob_{m}"]+globals()[f"nofacprob_{m}_pos"])/2
var_name = f"cauprob_{m}_ave"
globals()[var_name] = (globals()[f"cauprob_{m}"]+globals()[f"cauprob_{m}_pos"])/2
var_name = f"nocauprob_{m}_ave"
globals()[var_name] = (globals()[f"nocauprob_{m}"]+globals()[f"nocauprob_{m}_pos"])/2


#gpt
m='gpt'
df1fac = pd.read_csv(f'{base_path}fac_prob_part1.csv')
df2fac = pd.read_csv(f'{base_path}fac_prob_part2.csv')
df3fac = pd.read_csv(f'{base_path}fac_prob_part3.csv')
merged_dffac = pd.concat([df1fac, df2fac, df3fac], ignore_index=True)
df1cau = pd.read_csv(f'{base_path}cau_prob_part1.csv')
df2cau = pd.read_csv(f'{base_path}cau_prob_part2.csv')
df3cau = pd.read_csv(f'{base_path}cau_prob_part3.csv')
merged_dfcau = pd.concat([df1cau, df2cau, df3cau], ignore_index=True)

df1afac = pd.read_csv(f'{base_path}merged_part1_fac.csv')
df2afac = pd.read_csv(f'{base_path}merged_part2_fac.csv')
df3afac = pd.read_csv(f'{base_path}merged_part3_fac.csv')
merged_dfafac = pd.concat([df1afac, df2afac, df3afac], ignore_index=True)
df1acau = pd.read_csv(f'{base_path}merged_part1_cau.csv')
df2acau = pd.read_csv(f'{base_path}merged_part2_cau.csv')
df3acau = pd.read_csv(f'{base_path}merged_part3_cau.csv')
merged_dfacau = pd.concat([df1acau, df2acau, df3acau], ignore_index=True)

merged_dffac['origin'] = merged_dfafac['origin']
merged_dfcau['origin'] = merged_dfacau['origin']

fac = merged_dffac[merged_dffac["origin"] == 'fac']
nofac = merged_dffac[merged_dffac["origin"] == 'nofac']
#var_name = f"cau_{m}"
#globals()[var_name] 
cau = merged_dfcau[merged_dfcau["origin"] == 'cau']
nocau = merged_dfcau[merged_dfcau["origin"] == 'nocau']

var_name = f"facprob_{m}"
globals()[var_name] = fac['Prob_Yes']/(fac['Prob_Yes']+fac['Prob_No'])
var_name = f"nofacprob_{m}"
globals()[var_name] = nofac['Prob_Yes']/(nofac['Prob_Yes']+nofac['Prob_No'])
var_name = f"cauprob_{m}"
globals()[var_name] = cau['Prob_Yes']/(cau['Prob_Yes']+cau['Prob_No'])
var_name = f"nocauprob_{m}"
globals()[var_name] = nocau['Prob_Yes']/(nocau['Prob_Yes']+nocau['Prob_No'])


df1fac_pos = pd.read_csv(f'{base_path}fac_pos_prob_part1.csv')
df2fac_pos = pd.read_csv(f'{base_path}fac_pos_prob_part2.csv')
df3fac_pos = pd.read_csv(f'{base_path}fac_pos_prob_part3.csv')
merged_dffac_pos = pd.concat([df1fac_pos, df2fac_pos, df3fac_pos], ignore_index=True)
df1cau_pos = pd.read_csv(f'{base_path}cau_pos_prob_part1.csv')
df2cau_pos = pd.read_csv(f'{base_path}cau_pos_prob_part2.csv')
df3cau_pos = pd.read_csv(f'{base_path}cau_pos_prob_part3.csv')
merged_dfcau_pos = pd.concat([df1cau_pos, df2cau_pos, df3cau_pos], ignore_index=True)

df1afac = pd.read_csv(f'{base_path}merged_part1_fac.csv')
df2afac = pd.read_csv(f'{base_path}merged_part2_fac.csv')
df3afac = pd.read_csv(f'{base_path}merged_part3_fac.csv')
merged_dfafac = pd.concat([df1afac, df2afac, df3afac], ignore_index=True)
df1acau = pd.read_csv(f'{base_path}merged_part1_cau.csv')
df2acau = pd.read_csv(f'{base_path}merged_part2_cau.csv')
df3acau = pd.read_csv(f'{base_path}merged_part3_cau.csv')
merged_dfacau = pd.concat([df1acau, df2acau, df3acau], ignore_index=True)

merged_dffac_pos['origin'] = merged_dfafac['origin']
merged_dfcau_pos['origin'] = merged_dfacau['origin']

fac_pos = merged_dffac_pos[merged_dffac_pos["origin"] == 'fac']
nofac_pos = merged_dffac_pos[merged_dffac_pos["origin"] == 'nofac']
#var_name = f"cau_{m}"
#globals()[var_name] 
cau_pos = merged_dfcau_pos[merged_dfcau_pos["origin"] == 'cau']
nocau_pos = merged_dfcau_pos[merged_dfcau_pos["origin"] == 'nocau']

var_name = f"facprob_{m}_pos"
globals()[var_name] = fac_pos['Prob_Yes']/(fac_pos['Prob_Yes']+fac_pos['Prob_No'])
var_name = f"nofacprob_{m}_pos"
globals()[var_name] = nofac_pos['Prob_Yes']/(nofac_pos['Prob_Yes']+nofac_pos['Prob_No'])
var_name = f"cauprob_{m}_pos"
globals()[var_name] = cau_pos['Prob_Yes']/(cau_pos['Prob_Yes']+cau_pos['Prob_No'])
var_name = f"nocauprob_{m}_pos"
globals()[var_name] = nocau_pos['Prob_Yes']/(nocau_pos['Prob_Yes']+nocau_pos['Prob_No'])


var_name = f"facprob_{m}_ave"
globals()[var_name] = (globals()[f"facprob_{m}"]+globals()[f"facprob_{m}_pos"])/2
var_name = f"nofacprob_{m}_ave"
globals()[var_name] = (globals()[f"nofacprob_{m}"]+globals()[f"nofacprob_{m}_pos"])/2
var_name = f"cauprob_{m}_ave"
globals()[var_name] = (globals()[f"cauprob_{m}"]+globals()[f"cauprob_{m}_pos"])/2
var_name = f"nocauprob_{m}_ave"
globals()[var_name] = (globals()[f"nocauprob_{m}"]+globals()[f"nocauprob_{m}_pos"])/2





m='deberta'
merged_dffac = pd.read_csv(f'{base_path}nli_inference_{m}_fac.csv')
merged_dfcau = pd.read_csv(f'{base_path}nli_inference_{m}_cau.csv')

df1afac = pd.read_csv(f'{base_path}merged_part1_fac.csv')
df2afac = pd.read_csv(f'{base_path}merged_part2_fac.csv')
df3afac = pd.read_csv(f'{base_path}merged_part3_fac.csv')
merged_dfafac = pd.concat([df1afac, df2afac, df3afac], ignore_index=True)
df1acau = pd.read_csv(f'{base_path}merged_part1_cau.csv')
df2acau = pd.read_csv(f'{base_path}merged_part2_cau.csv')
df3acau = pd.read_csv(f'{base_path}merged_part3_cau.csv')
merged_dfacau = pd.concat([df1acau, df2acau, df3acau], ignore_index=True)

merged_dffac['origin'] = merged_dfafac['origin']
merged_dfcau['origin'] = merged_dfacau['origin']

fac = merged_dffac[merged_dffac["origin"] == 'fac']
nofac = merged_dffac[merged_dffac["origin"] == 'nofac']
#var_name = f"cau_{m}"
#globals()[var_name] 
cau = merged_dfcau[merged_dfcau["origin"] == 'cau']
nocau = merged_dfcau[merged_dfcau["origin"] == 'nocau']

var_name = f"facprob_{m}"
globals()[var_name] = fac['entailment_prob']/(fac['entailment_prob']+fac['contradiction_prob'])
var_name = f"nofacprob_{m}"
globals()[var_name] = nofac['entailment_prob']/(nofac['entailment_prob']+nofac['contradiction_prob'])
var_name = f"cauprob_{m}"
globals()[var_name] = cau['entailment_prob']/(cau['entailment_prob']+cau['contradiction_prob'])
var_name = f"nocauprob_{m}"
globals()[var_name] = nocau['entailment_prob']/(nocau['entailment_prob']+nocau['contradiction_prob'])


m='roberta'
merged_dffac = pd.read_csv(f'{base_path}nli_inference_{m}_fac.csv')
merged_dfcau = pd.read_csv(f'{base_path}nli_inference_{m}_cau.csv')

df1afac = pd.read_csv(f'{base_path}merged_part1_fac.csv')
df2afac = pd.read_csv(f'{base_path}merged_part2_fac.csv')
df3afac = pd.read_csv(f'{base_path}merged_part3_fac.csv')
merged_dfafac = pd.concat([df1afac, df2afac, df3afac], ignore_index=True)
df1acau = pd.read_csv(f'{base_path}merged_part1_cau.csv')
df2acau = pd.read_csv(f'{base_path}merged_part2_cau.csv')
df3acau = pd.read_csv(f'{base_path}merged_part3_cau.csv')
merged_dfacau = pd.concat([df1acau, df2acau, df3acau], ignore_index=True)

merged_dffac['origin'] = merged_dfafac['origin']
merged_dfcau['origin'] = merged_dfacau['origin']

fac = merged_dffac[merged_dffac["origin"] == 'fac']
nofac = merged_dffac[merged_dffac["origin"] == 'nofac']
#var_name = f"cau_{m}"
#globals()[var_name] 
cau = merged_dfcau[merged_dfcau["origin"] == 'cau']
nocau = merged_dfcau[merged_dfcau["origin"] == 'nocau']

var_name = f"facprob_{m}"
globals()[var_name] = fac['entailment_prob']/(fac['entailment_prob']+fac['contradiction_prob'])
var_name = f"nofacprob_{m}"
globals()[var_name] = nofac['entailment_prob']/(nofac['entailment_prob']+nofac['contradiction_prob'])
var_name = f"cauprob_{m}"
globals()[var_name] = cau['entailment_prob']/(cau['entailment_prob']+cau['contradiction_prob'])
var_name = f"nocauprob_{m}"
globals()[var_name] = nocau['entailment_prob']/(nocau['entailment_prob']+nocau['contradiction_prob'])


m='bart'
merged_dffac = pd.read_csv(f'{base_path}nli_inference_{m}_fac.csv')
merged_dfcau = pd.read_csv(f'{base_path}nli_inference_{m}_cau.csv')

df1afac = pd.read_csv(f'{base_path}merged_part1_fac.csv')
df2afac = pd.read_csv(f'{base_path}merged_part2_fac.csv')
df3afac = pd.read_csv(f'{base_path}merged_part3_fac.csv')
merged_dfafac = pd.concat([df1afac, df2afac, df3afac], ignore_index=True)
df1acau = pd.read_csv(f'{base_path}merged_part1_cau.csv')
df2acau = pd.read_csv(f'{base_path}merged_part2_cau.csv')
df3acau = pd.read_csv(f'{base_path}merged_part3_cau.csv')
merged_dfacau = pd.concat([df1acau, df2acau, df3acau], ignore_index=True)

merged_dffac['origin'] = merged_dfafac['origin']
merged_dfcau['origin'] = merged_dfacau['origin']

fac = merged_dffac[merged_dffac["origin"] == 'fac']
nofac = merged_dffac[merged_dffac["origin"] == 'nofac']
#var_name = f"cau_{m}"
#globals()[var_name] 
cau = merged_dfcau[merged_dfcau["origin"] == 'cau']
nocau = merged_dfcau[merged_dfcau["origin"] == 'nocau']

var_name = f"facprob_{m}"
globals()[var_name] = fac['entailment_prob']/(fac['entailment_prob']+fac['contradiction_prob'])
var_name = f"nofacprob_{m}"
globals()[var_name] = nofac['entailment_prob']/(nofac['entailment_prob']+nofac['contradiction_prob'])
var_name = f"cauprob_{m}"
globals()[var_name] = cau['entailment_prob']/(cau['entailment_prob']+cau['contradiction_prob'])
var_name = f"nocauprob_{m}"
globals()[var_name] = nocau['entailment_prob']/(nocau['entailment_prob']+nocau['contradiction_prob'])

# %%
roberta_deberta = round(ranksums(facprob_roberta,facprob_deberta, alternative='less').pvalue,2)
bart_deberta = round(ranksums(facprob_bart,facprob_deberta, alternative='less').pvalue,2)
gemma_2_2b_deberta = round(ranksums(facprob_gemma_2_2b_ave,facprob_deberta, alternative='less').pvalue,2)
gemma_2_9b_deberta = round(ranksums(facprob_gemma_2_9b_ave,facprob_deberta, alternative='less').pvalue,2)
llama_32_3b_deberta = round(ranksums(facprob_llama_32_3b_ave,facprob_deberta, alternative='less').pvalue,2)
llama_31_8b_deberta = round(ranksums(facprob_llama_31_8b_ave,facprob_deberta, alternative='less').pvalue,2)
phi_35_mini_deberta = round(ranksums(facprob_phi_35_mini_ave,facprob_deberta, alternative='less').pvalue,2)
phi_35_MoE_deberta = round(ranksums(facprob_phi_35_MoE_ave,facprob_deberta, alternative='less').pvalue,2)
gpt_deberta = round(ranksums(facprob_gpt_ave,facprob_deberta, alternative='less').pvalue,2)

deberta_roberta = round(ranksums(facprob_deberta,facprob_roberta, alternative='less').pvalue,2)
bart_roberta = round(ranksums(facprob_bart,facprob_roberta, alternative='less').pvalue,2)
gemma_2_2b_roberta = round(ranksums(facprob_gemma_2_2b_ave,facprob_roberta, alternative='less').pvalue,2)
gemma_2_9b_roberta = round(ranksums(facprob_gemma_2_9b_ave,facprob_roberta, alternative='less').pvalue,2)
llama_32_3b_roberta = round(ranksums(facprob_llama_32_3b_ave,facprob_roberta, alternative='less').pvalue,2)
llama_31_8b_roberta = round(ranksums(facprob_llama_31_8b_ave,facprob_roberta, alternative='less').pvalue,2)
phi_35_mini_roberta = round(ranksums(facprob_phi_35_mini_ave,facprob_roberta, alternative='less').pvalue,2)
phi_35_MoE_roberta = round(ranksums(facprob_phi_35_MoE_ave,facprob_roberta, alternative='less').pvalue,2)
gpt_roberta = round(ranksums(facprob_gpt_ave,facprob_roberta, alternative='less').pvalue,2)

deberta_bart = round(ranksums(facprob_deberta,facprob_bart, alternative='less').pvalue,2)
roberta_bart = round(ranksums(facprob_roberta,facprob_bart, alternative='less').pvalue,2)
gemma_2_2b_bart = round(ranksums(facprob_gemma_2_2b_ave,facprob_bart, alternative='less').pvalue,2)
gemma_2_9b_bart = round(ranksums(facprob_gemma_2_9b_ave,facprob_bart, alternative='less').pvalue,2)
llama_32_3b_bart = round(ranksums(facprob_llama_32_3b_ave,facprob_bart, alternative='less').pvalue,2)
llama_31_8b_bart = round(ranksums(facprob_llama_31_8b_ave,facprob_bart, alternative='less').pvalue,2)
phi_35_mini_bart = round(ranksums(facprob_phi_35_mini_ave,facprob_bart, alternative='less').pvalue,2)
phi_35_MoE_bart = round(ranksums(facprob_phi_35_MoE_ave,facprob_bart, alternative='less').pvalue,2)
gpt_bart = round(ranksums(facprob_gpt_ave,facprob_bart, alternative='less').pvalue,2)

deberta_gemma_2_2b = round(ranksums(facprob_deberta,facprob_gemma_2_2b_ave, alternative='less').pvalue,2)
roberta_gemma_2_2b = round(ranksums(facprob_roberta,facprob_gemma_2_2b_ave, alternative='less').pvalue,2)
bart_gemma_2_2b = round(ranksums(facprob_bart,facprob_gemma_2_2b_ave, alternative='less').pvalue,2)
gemma_2_9b_gemma_2_2b = round(ranksums(facprob_gemma_2_9b_ave,facprob_gemma_2_2b_ave, alternative='less').pvalue,2)
llama_32_3b_gemma_2_2b = round(ranksums(facprob_llama_32_3b_ave,facprob_gemma_2_2b_ave, alternative='less').pvalue,2)
llama_31_8b_gemma_2_2b = round(ranksums(facprob_llama_31_8b_ave,facprob_gemma_2_2b_ave, alternative='less').pvalue,2)
phi_35_mini_gemma_2_2b = round(ranksums(facprob_phi_35_mini_ave,facprob_gemma_2_2b_ave, alternative='less').pvalue,2)
phi_35_MoE_gemma_2_2b = round(ranksums(facprob_phi_35_MoE_ave,facprob_gemma_2_2b_ave, alternative='less').pvalue,2)
gpt_gemma_2_2b = round(ranksums(facprob_gpt_ave,facprob_gemma_2_2b_ave, alternative='less').pvalue,2)

deberta_gemma_2_9b = round(ranksums(facprob_deberta,facprob_gemma_2_9b_ave, alternative='less').pvalue,2)
roberta_gemma_2_9b = round(ranksums(facprob_roberta,facprob_gemma_2_9b_ave, alternative='less').pvalue,2)
bart_gemma_2_9b = round(ranksums(facprob_bart,facprob_gemma_2_9b_ave, alternative='less').pvalue,2)
gemma_2_2b_gemma_2_9b = round(ranksums(facprob_gemma_2_2b_ave,facprob_gemma_2_9b_ave, alternative='less').pvalue,2)
llama_32_3b_gemma_2_9b = round(ranksums(facprob_llama_32_3b_ave,facprob_gemma_2_9b_ave, alternative='less').pvalue,2)
llama_31_8b_gemma_2_9b = round(ranksums(facprob_llama_31_8b_ave,facprob_gemma_2_9b_ave, alternative='less').pvalue,2)
phi_35_mini_gemma_2_9b = round(ranksums(facprob_phi_35_mini_ave,facprob_gemma_2_9b_ave, alternative='less').pvalue,2)
phi_35_MoE_gemma_2_9b = round(ranksums(facprob_phi_35_MoE_ave,facprob_gemma_2_9b_ave, alternative='less').pvalue,2)
gpt_gemma_2_9b = round(ranksums(facprob_gpt_ave,facprob_gemma_2_9b_ave, alternative='less').pvalue,2)

deberta_llama_32_3b = round(ranksums(facprob_deberta,facprob_llama_32_3b_ave, alternative='less').pvalue,2)
roberta_llama_32_3b = round(ranksums(facprob_roberta,facprob_llama_32_3b_ave, alternative='less').pvalue,2)
bart_llama_32_3b = round(ranksums(facprob_bart,facprob_llama_32_3b_ave, alternative='less').pvalue,2)
gemma_2_2b_llama_32_3b = round(ranksums(facprob_gemma_2_2b_ave,facprob_llama_32_3b_ave, alternative='less').pvalue,2)
gemma_2_9b_llama_32_3b = round(ranksums(facprob_gemma_2_9b_ave,facprob_llama_32_3b_ave, alternative='less').pvalue,2)
llama_31_8b_llama_32_3b = round(ranksums(facprob_llama_31_8b_ave,facprob_llama_32_3b_ave, alternative='less').pvalue,2)
phi_35_mini_llama_32_3b = round(ranksums(facprob_phi_35_mini_ave,facprob_llama_32_3b_ave, alternative='less').pvalue,2)
phi_35_MoE_llama_32_3b = round(ranksums(facprob_phi_35_MoE_ave,facprob_llama_32_3b_ave, alternative='less').pvalue,2)
gpt_llama_32_3b = round(ranksums(facprob_gpt_ave,facprob_llama_32_3b_ave, alternative='less').pvalue,2)

deberta_llama_31_8b = round(ranksums(facprob_deberta,facprob_llama_31_8b_ave, alternative='less').pvalue,2)
roberta_llama_31_8b = round(ranksums(facprob_roberta,facprob_llama_31_8b_ave, alternative='less').pvalue,2)
bart_llama_31_8b = round(ranksums(facprob_bart,facprob_llama_31_8b_ave, alternative='less').pvalue,2)
gemma_2_2b_llama_31_8b = round(ranksums(facprob_gemma_2_2b_ave,facprob_llama_31_8b_ave, alternative='less').pvalue,2)
gemma_2_9b_llama_31_8b = round(ranksums(facprob_gemma_2_9b_ave,facprob_llama_31_8b_ave, alternative='less').pvalue,2)
llama_32_3b_llama_31_8b = round(ranksums(facprob_llama_32_3b_ave,facprob_llama_31_8b_ave, alternative='less').pvalue,2)
phi_35_mini_llama_31_8b = round(ranksums(facprob_phi_35_mini_ave,facprob_llama_31_8b_ave, alternative='less').pvalue,2)
phi_35_MoE_llama_31_8b = round(ranksums(facprob_phi_35_MoE_ave,facprob_llama_31_8b_ave, alternative='less').pvalue,2)
gpt_llama_31_8b = round(ranksums(facprob_gpt_ave,facprob_llama_31_8b_ave, alternative='less').pvalue,2)

deberta_phi_35_mini= round(ranksums(facprob_deberta,facprob_phi_35_mini_ave, alternative='less').pvalue,2)
roberta_phi_35_mini = round(ranksums(facprob_roberta,facprob_phi_35_mini_ave, alternative='less').pvalue,2)
bart_phi_35_mini = round(ranksums(facprob_bart,facprob_phi_35_mini_ave, alternative='less').pvalue,2)
gemma_2_2b_phi_35_mini = round(ranksums(facprob_gemma_2_2b_ave,facprob_phi_35_mini_ave, alternative='less').pvalue,2)
gemma_2_9b_phi_35_mini = round(ranksums(facprob_gemma_2_9b_ave,facprob_phi_35_mini_ave, alternative='less').pvalue,2)
llama_32_3b_phi_35_mini = round(ranksums(facprob_llama_32_3b_ave,facprob_phi_35_mini_ave, alternative='less').pvalue,2)
llama_31_8b_phi_35_mini = round(ranksums(facprob_llama_31_8b_ave,facprob_phi_35_mini_ave, alternative='less').pvalue,2)
phi_35_MoE_phi_35_mini = round(ranksums(facprob_phi_35_MoE_ave,facprob_phi_35_mini_ave, alternative='less').pvalue,2)
gpt_phi_35_mini = round(ranksums(facprob_gpt_ave,facprob_phi_35_mini_ave, alternative='less').pvalue,2)

deberta_phi_35_MoE= round(ranksums(facprob_deberta,facprob_phi_35_MoE_ave, alternative='less').pvalue,2)
roberta_phi_35_MoE = round(ranksums(facprob_roberta,facprob_phi_35_MoE_ave, alternative='less').pvalue,2)
bart_phi_35_MoE = round(ranksums(facprob_bart,facprob_phi_35_MoE_ave, alternative='less').pvalue,2)
gemma_2_2b_phi_35_MoE = round(ranksums(facprob_gemma_2_2b_ave,facprob_phi_35_MoE_ave, alternative='less').pvalue,2)
gemma_2_9b_phi_35_MoE = round(ranksums(facprob_gemma_2_9b_ave,facprob_phi_35_MoE_ave, alternative='less').pvalue,2)
llama_32_3b_phi_35_MoE = round(ranksums(facprob_llama_32_3b_ave,facprob_phi_35_MoE_ave, alternative='less').pvalue,2)
llama_31_8b_phi_35_MoE = round(ranksums(facprob_llama_31_8b_ave,facprob_phi_35_MoE_ave, alternative='less').pvalue,2)
phi_35_mini_phi_35_MoE = round(ranksums(facprob_phi_35_mini_ave,facprob_phi_35_MoE_ave, alternative='less').pvalue,2)
gpt_phi_35_MoE = round(ranksums(facprob_gpt_ave,facprob_phi_35_MoE_ave, alternative='less').pvalue,2)

deberta_gpt= round(ranksums(facprob_deberta,facprob_gpt_ave, alternative='less').pvalue,2)
roberta_gpt = round(ranksums(facprob_roberta,facprob_gpt_ave, alternative='less').pvalue,2)
bart_gpt = round(ranksums(facprob_bart,facprob_gpt_ave, alternative='less').pvalue,2)
gemma_2_2b_gpt = round(ranksums(facprob_gemma_2_2b_ave,facprob_gpt_ave, alternative='less').pvalue,2)
gemma_2_9b_gpt = round(ranksums(facprob_gemma_2_9b_ave,facprob_gpt_ave, alternative='less').pvalue,2)
llama_32_3b_gpt = round(ranksums(facprob_llama_32_3b_ave,facprob_gpt_ave, alternative='less').pvalue,2)
llama_31_8b_gpt = round(ranksums(facprob_llama_31_8b_ave,facprob_gpt_ave, alternative='less').pvalue,2)
phi_35_mini_gpt = round(ranksums(facprob_phi_35_mini_ave,facprob_gpt_ave, alternative='less').pvalue,2)
phi_35_MoE_gpt = round(ranksums(facprob_phi_35_MoE_ave, facprob_gpt_ave, alternative='less').pvalue,2)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
model_names = ['DeBERTa-v3-large', 'RoBERTa-large', 'BART-large', 'Gemma-2-2B', 'Gemma-2-9B', 'Llama-3.2-3B', 'Llama-3.1-8B' ,'Phi-3.5-mini', 'Phi-3.5-MoE','GPT-4o']
pval_list =[0.5,roberta_deberta,bart_deberta,gemma_2_2b_deberta,gemma_2_9b_deberta, llama_32_3b_deberta, llama_31_8b_deberta, phi_35_mini_deberta, phi_35_MoE_deberta, gpt_deberta,
            deberta_roberta,0.5,bart_roberta,gemma_2_2b_roberta,gemma_2_9b_roberta, llama_32_3b_roberta, llama_31_8b_roberta, phi_35_mini_roberta, phi_35_MoE_roberta, gpt_roberta,
            deberta_bart,roberta_bart,0.5,gemma_2_2b_bart,gemma_2_9b_bart, llama_32_3b_bart, llama_31_8b_bart, phi_35_mini_bart, phi_35_MoE_bart, gpt_bart,
            deberta_gemma_2_2b,roberta_gemma_2_2b,bart_gemma_2_2b,0.5,gemma_2_9b_gemma_2_2b,llama_32_3b_gemma_2_2b,llama_31_8b_gemma_2_2b,phi_35_mini_gemma_2_2b,phi_35_MoE_gemma_2_2b, gpt_gemma_2_2b,
            deberta_gemma_2_9b,roberta_gemma_2_9b,bart_gemma_2_9b,gemma_2_2b_gemma_2_9b,0.5,llama_32_3b_gemma_2_9b,llama_31_8b_gemma_2_9b,phi_35_mini_gemma_2_9b,phi_35_MoE_gemma_2_9b,gpt_gemma_2_9b,
            deberta_llama_32_3b,roberta_llama_32_3b,bart_llama_32_3b,gemma_2_2b_llama_32_3b,gemma_2_9b_llama_32_3b,0.5,llama_31_8b_llama_32_3b,phi_35_mini_llama_32_3b,phi_35_MoE_llama_32_3b,gpt_llama_32_3b,
            deberta_llama_31_8b,roberta_llama_31_8b,bart_llama_31_8b,gemma_2_2b_llama_31_8b,gemma_2_9b_llama_31_8b,llama_32_3b_llama_31_8b,0.5,phi_35_mini_llama_31_8b,phi_35_MoE_llama_31_8b,gpt_llama_31_8b,
            deberta_phi_35_mini,roberta_phi_35_mini,bart_phi_35_mini,gemma_2_2b_phi_35_mini,gemma_2_9b_phi_35_mini,llama_32_3b_phi_35_mini,llama_31_8b_phi_35_mini,0.5,phi_35_MoE_phi_35_mini,gpt_phi_35_mini,
            deberta_phi_35_MoE,roberta_phi_35_MoE,bart_phi_35_MoE,gemma_2_2b_phi_35_MoE,gemma_2_9b_phi_35_MoE,llama_32_3b_phi_35_MoE,llama_31_8b_phi_35_MoE,phi_35_mini_phi_35_MoE,0.5,gpt_phi_35_MoE,
            deberta_gpt,roberta_gpt,bart_gpt,gemma_2_2b_gpt,gemma_2_9b_gpt,llama_32_3b_gpt,llama_31_8b_gpt,phi_35_mini_gpt,phi_35_MoE_gpt,0.5
            ]

pval_array = np.array(pval_list).reshape(10, 10)


annot_array = np.empty_like(pval_array, dtype=object)
for i in range(10):
    for j in range(10):
        val = pval_array[i, j]
        if val > 0.90:
            annot_array[i, j] = ">0.90"
        elif val < 0.01:
            annot_array[i, j] = "<0.01"
        else:
            annot_array[i, j] = f"{val:.2f}"


plt.figure(figsize=(7, 6))
sns.heatmap(
    pval_array,               
    annot=annot_array,        
    fmt='',                    
    cmap="Blues_r",
    xticklabels=model_names,
    yticklabels=model_names,
    cbar_kws={'label': 'p-value'},
    linewidths=0.5,
    linecolor='gray'
)


#plt.title("9x9 Pairwise Model p-value Heatmap with factuality issues")
plt.xticks(rotation=45, ha='right')  
plt.yticks(rotation=0)
plt.tight_layout()
#plt.savefig(f"{base_path}heatmap_withfacgpt.png", dpi=1000, bbox_inches='tight')
plt.show()
